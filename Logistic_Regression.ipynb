# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakSaran/SOC-midterm-review/blob/main/Logistic_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
# %matplotlib inline

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/folder/insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
plt.scatter(df.age, df.bought_insurance, marker='.', color='red')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.bought_insurance, train_size=0.9)

# %%
X_train
# Out:
#     age
# 21   26
# 15   55
# 23   45
# 22   40
# 5    56
# 12   27
# 9    61
# 1    25
# 19   18
# 10   18
# 8    62
# 18   19
# 13   29
# 25   54
# 0    22
# 7    60
# 14   49
# 17   58
# 11   28
# 26   23
# 3    52
# 6    55
# 2    47
# 20   21

# %%
X_test
# Out:
#     age
# 16   25
# 24   50
# 4    46

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(X_test)
# Out:
# array([0, 1, 1])

# %%
model.score(X_test, y_test)
# Out:
# 0.6666666666666666

# %%
model.predict_proba(X_test)
# Out:
# array([[0.95125182, 0.04874818],
#        [0.23244537, 0.76755463],
#        [0.37097228, 0.62902772]])

# %%
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([0, 1, 1])
